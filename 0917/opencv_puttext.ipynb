# %%
# %load opencv_show_image.py
"""
Created on Tue Sep 10 22:18:29 2019

@author: CV
"""

#display an image

import cv2
import numpy

img = cv2.imread('sakura.jpg')
print(str(type(img)))
cv2.imshow('Color', img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>

# %%
#convert to grayscale and display an image

import cv2
import numpy

input_img = cv2.imread('sakura.jpg')
height, width, channels = input_img.shape
print(height, width, channels)

gray_img = cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
height, width = gray_img.shape
print(height, width)

cv2.imshow('Grayscale', gray_img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 225 225 3
# 225 225

# %%
#putText in an image and write to a file

import cv2
import numpy

img = cv2.imread('sakura.jpg')
print(type(img))
height, width, channels = img.shape
print(height, width, channels)

cv2.putText(img, "FPS" , (0, height), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2)
"""
cv2.putText(img, text, org, fontFace, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])
org = position
fontFace = words type
color = (B,G,R)
"""
cv2.imwrite('sakura_text.png', img)
cv2.imshow('putText', img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# 225 225 3

# %%
# %%writefile test.py
#display an image

import cv2
import numpy
img = cv2.imread('sakura.jpg')
print(str(type(img)))
cv2.imshow('Color', img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Overwriting test.py

# %% [markdown]
# %%writefile test
# ## Practice
# 1. Read an image from file
# 2. Draw two lines
# 3. Draw a circle
# 4. Draw a rectangle
# 5. Draw text (your student id)
# 6. Show the image
# 7. Write the image to file
# 8. Upload your image file

# %%
import cv2
import numpy
# Read an image from file
img = cv2.imread('sakura.jpg')

# Draw two lines
cv2.line(img, (50, 5), (225, 5), (255, 0, 0), 1)
cv2.line(img, (0, 10), (200, 10), (0, 255, 0), 2)

# Draw a circle
cv2.circle(img, (150, 150), 30, (0, 0, 255), 3)
cv2.circle(img, (150, 150), 10, (0, 255, 255), -1)

# Draw a rectangle
cv2.rectangle(img, (0, 200), (175,224), (255, 255, 0), 2)

# Draw text (your student id)
cv2.putText(img, "611421201" , (0, 222), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2)

# Write the image to file
cv2.imwrite('611421201_practice_0917.png', img)

cv2.imshow('Color', img)
cv2.waitKey()
cv2.destroyAllWindows()
