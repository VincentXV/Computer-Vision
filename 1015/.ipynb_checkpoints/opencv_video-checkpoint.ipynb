# %%
#read video file

import cv2
cap = cv2.VideoCapture(0)
# Check if the webcam is opened correctly
if not cap.isOpened():
    raise IOError("Cannot open webcam")
while True:
    ret, frame = cap.read()
    #frame = cv2.resize(frame, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
    cv2.imshow('Input', frame)
    c = cv2.waitKey(1)
    if c == 27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
#read video file (specific frames)

import cv2

cap = cv2.VideoCapture('WiiPlay.mp4')
# Check if the video file is opened correctly
if not cap.isOpened():
    raise IOError("Cannot open the video file")
    
#BE CAREFUL! Each video has different time length and frame rate. 
#So make sure that you have the right parameters for the right video!
#time_length = 1481.0
#fps=30
frame_seq = 44000

#The first argument flag CAP_PROP_POS_FRAMES is a 0-based index of the frame to be decoded/captured next.
#The second argument defines the frame number in range from 0 to (time_length*fps - 1).
cap.set(cv2.CAP_PROP_POS_FRAMES , frame_seq);

ret, frame = cap.read()
cur_frame = cv2.resize(frame, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
while True:
    ret, frame = cap.read()
    if ret == False:
        break
    cur_frame = cv2.resize(frame, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)   
    cv2.imshow('downsampling', cur_frame)
    c = cv2.waitKey(1)
    if c == 27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
#write video file

import cv2

cap = cv2.VideoCapture('WiiPlay.mp4')
# Check if the video file is opened correctly
if not cap.isOpened():
    raise IOError("Cannot open the video file")
    
#BE CAREFUL! Each video has different time length and frame rate. 
#So make sure that you have the right parameters for the right video!
time_length = 1481.0
fps=30
frame_seq = 44000
out_size = (640, 360)

# 使用 X264 編碼
#fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# 建立 VideoWriter 物件，輸出影片至 output.mp4
# FPS 值為 30.0，解析度為 640x360
out = cv2.VideoWriter('output.mp4', fourcc, 30.0, out_size)

#The first argument flag CAP_PROP_POS_FRAMES is a 0-based index of the frame to be decoded/captured next.
#The second argument defines the frame number in range from 0 to (time_length*fps - 1).
cap.set(cv2.CAP_PROP_POS_FRAMES , frame_seq);

ret, frame = cap.read()
cur_frame = cv2.resize(frame, out_size, 0, 0, interpolation=cv2.INTER_AREA)
while True:
    ret, frame = cap.read()
    if ret == False:
        break
    cur_frame = cv2.resize(frame, out_size, 0, 0, interpolation=cv2.INTER_AREA)   
    cv2.imshow('downsampling', cur_frame)
    out.write(cur_frame)
    c = cv2.waitKey(1)
    if c == 27:
        break
cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## %%writefile test
# ## Practice
# 1. Read continuous images from <i>WiiPlay.mp4</i> video file. (with level number the same as the last two digits of your student id)
# 2. Detect the blue cursor and mark its location using a rectangle. (hint: use <i>inRange()</i>)
# 3. Show the images.
# 4. Write the images to <i>Output.mp4</i> video file.
# 5. Upload your Jupyter code file (*.ipynb)

# %%
'''
611421201 so I should show the level 01
start = 5
final = 14
'''
import cv2
import numpy as np

cap = cv2.VideoCapture('WiiPlay.mp4')
# Check if the video file is opened correctly
if not cap.isOpened():
    raise IOError("Cannot open the video file")
    
#BE CAREFUL! Each video has different time length and frame rate. 
#So make sure that you have the right parameters for the right video!
#time_length = 1481.0
fps=30
s_frame_seq = 5 * fps
f_frame_seq = 14 * fps
out_size = (640, 360)

# blue bound
lower_blue = np.array([200, 50, 0])
upper_blue = np.array([255, 140, 30])

# 使用 X264 編碼
#fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# 建立 VideoWriter 物件，輸出影片至 output.mp4
# FPS 值為 30.0，解析度為 640x360
out = cv2.VideoWriter('pratice_611421201.mp4', fourcc, 30.0, out_size)

#The first argument flag CAP_PROP_POS_FRAMES is a 0-based index of the frame to be decoded/captured next.
#The second argument defines the frame number in range from 0 to (time_length*fps - 1).
cap.set(cv2.CAP_PROP_POS_FRAMES , s_frame_seq);

ret, frame = cap.read()
cur_frame = cv2.resize(frame, out_size, 0, 0, interpolation=cv2.INTER_AREA)
rows, cols, channels = cur_frame.shape
print(rows, cols, channels)
while True:
    no_draw_yet = True
    ret, frame = cap.read()
    current_frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES)
    if current_frame_number == f_frame_seq:
        break
        
    cur_frame = cv2.resize(frame, out_size, 0, 0, interpolation=cv2.INTER_AREA)   
    dst = cv2.inRange(cur_frame, lower_blue, upper_blue)

    white = cv2.findNonZero(dst)
    if white is not None:
        white_points = white.reshape(-1, 2).tolist()
        pt0 = tuple(white_points[0])
        pt1 = pt0 + (-5, -5)
        pt2 = pt0 + (10, 10)
        
        pt1 = tuple(pt1_np)
        pt2 = tuple(pt2_np)
        #print(white_points[0])
        cur_frame = cv2.rectangle(cur_frame, pt1, pt2, color, 1)
    
    cv2.imshow('downsampling', cur_frame)
    cv2.imshow('mask', dst)
    out.write(cur_frame)
    
    c = cv2.waitKey(1)
    if c == 27:
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 360 640 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 55
#      53 if white is not None:
#      54     white_points = white.reshape(-1, 2).tolist()
# ---> 55     pt1 = white_points[0] + (-5, -5)
#      56     pt2 = white_points[0] + (10, 10)
#      57     #print(white_points[0])
#
# TypeError: can only concatenate list (not "tuple") to list

# %%
R 0 ~ 23
G 134 ~ 121
B 255 ~ 209
